# %%
import pandas as pd
import numpy as np
import os
import pprint

# %matplotlib inline
import matplotlib as plt
import seaborn as sns

import nba_acquire

# %%
nba_acquire.get_player_data()
# Out:
# Player Data Information
# Consisting of 4550 rows and 8 columns
# It has loads of data, but also has 341 missing values.
#                      name  year_start  year_end position  height_inches  \
# 0          Alaa Abdelnaby        1991      1995      F-C             82
# 1         Zaid Abdul-Aziz        1969      1978      C-F             81
# 2     Kareem Abdul-Jabbar        1970      1989        C             86
# 3      Mahmoud Abdul-Rauf        1991      2001        G             73
# 4       Tariq Abdul-Wahad        1998      2003        F             78
# ...                   ...         ...       ...      ...            ...
# 4545           Ante Zizic        2018      2018      F-C             83
# 4546             Jim Zoet        1983      1983        C             85
# 4547            Bill Zopf        1971      1971        G             73
# 4548          Ivica Zubac        2017      2018        C             85
# ...

# %%
nba_acquire.players_info()
# Out:
# Player Data Information
# Consisting of 3922 rows and 8 columns
# Not all data is present.  We still have 1306 missing values.
#                  Player  height_inches  weight_lbs  \
# 0       Curly Armstrong             70         169
# 1          Cliff Barker             74         182
# 2         Leo Barnhorst             75         189
# 3            Ed Bartels             77         193
# 4           Ralph Beard             70         173
# ...                 ...            ...         ...
# 3917      Troy Williams             77         213
# 3918       Kyle Wiltjer             81         237
# 3919  Stephen Zimmerman             83         237
# 3920        Paul Zipser             79         213
# 3921        Ivica Zubac             85         264
#
#                               college  born      birth_city  \
# 0                  Indiana University  1918   Not Available
# 1              University of Kentucky  1921        Yorktown
# ...

# %%
nba_acquire.seasons_stats()
# Out:
# Statistical Information by Season
# Consisting of 24691 rows and 53 columns
# While informative, still needs work: we are missing 154919 values.
#        year             player position  age team  games  games_started  \
# 0      1950    Curly Armstrong      G-F   31  FTW     63              1
# 1      1950       Cliff Barker       SG   29  INO     49              1
# 2      1950      Leo Barnhorst       SF   25  CHS     67              1
# 3      1950         Ed Bartels        F   24  TOT     15              1
# 4      1950         Ed Bartels        F   24  DNN     13              1
# ...     ...                ...      ...  ...  ...    ...            ...
# 24686  2017        Cody Zeller       PF   24  CHO     62             58
# 24687  2017       Tyler Zeller        C   27  BOS     51              5
# 24688  2017  Stephen Zimmerman        C   20  ORL     19              0
# 24689  2017        Paul Zipser       SF   22  CHI     44             18
# ...

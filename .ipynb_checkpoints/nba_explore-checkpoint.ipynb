# %%
import pandas as pd
import numpy as np
import os
import pprint

from sklearn import preprocessing
from sklearn.model_selection import train_test_split


# %matplotlib inline
import matplotlib as plt
import seaborn as sns

import warnings
warnings.filterwarnings("ignore")

import nba_acquire
import nba_preprocessing

np.random.seed(123)
# Out:
# Player Data Information
# Consisting of 4550 rows and 8 columns
# It has loads of data, but also has 341 missing values.
# Player Data Information
# Consisting of 3922 rows and 8 columns
# Not all data is present.  We still have 1306 missing values.
# Statistical Information by Season
# Consisting of 24691 rows and 53 columns
# While informative, still needs work: we are missing 154919 values.

# %%
final_df = nba_preprocessing.final_df()

player_data_df = nba_acquire.player_data()
# Out:
# Final DataFrame
# Consisting of player_data_df, players_df, and seasons_stats_df.
# It contains 3921 rows and 53 columns
# It has loads of data, but also has 0 missing values.
# Player Data Information
# Consisting of 4550 rows and 8 columns
# It has loads of data, but also has 341 missing values.

# %%
final_df.head()
# Out:
#                 position  age  height_inches  weight_lbs team  \
# player
# Curly Armstrong      G-F   31             71         170  FTW
# Cliff Barker          SG   29             74         185  INO
# Leo Barnhorst         SF   25             76         190  CHS
# Ed Bartels             F   24             77         195  TOT
# Ralph Beard            G   22             70         175  INO
#
#                     date_of_birth  birth_city  birth_state  season  \
# player
# Curly Armstrong  November 1, 1918           1            1    1950
# Cliff Barker     January 15, 1921           1            1    1950
# Leo Barnhorst        May 11, 1924           1            1    1950
# Ed Bartels        October 8, 1925           1            1    1950
# Ralph Beard      December 2, 1927           1            1    1950
#
#                                          college  games  games_started  \
# player
# Curly Armstrong               Indiana University     63              1
# ...

# %%
final_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 3921 entries, Curly Armstrong to Ivica Zubac
# Data columns (total 53 columns):
# position                  3921 non-null object
# age                       3921 non-null int64
# height_inches             3921 non-null int64
# weight_lbs                3921 non-null int64
# team                      3921 non-null object
# date_of_birth             3921 non-null object
# birth_city                3921 non-null int64
# birth_state               3921 non-null int64
# season                    3921 non-null int64
# college                   3921 non-null object
# games                     3921 non-null int64
# games_started             3921 non-null int64
# minutes_played            3921 non-null int64
# usage_%                   3921 non-null float64
# total_points              3921 non-null int64
# field_goals_made          3921 non-null int64
# field_goal_attempts       3921 non-null int64
# ...

# %%
final_df.tail()
# Out:
#                   position  age  height_inches  weight_lbs team  \
# player
# Troy Williams           SF   22             79         218  TOT
# Kyle Wiltjer            PF   24             82         240  HOU
# Stephen Zimmerman        C   20             84         240  ORL
# Paul Zipser             SF   22             80         215  CHI
# Ivica Zubac              C   19             85         265  LAL
#
#                        date_of_birth  birth_city  birth_state  season  \
# player
# Troy Williams      December 30, 1994           1            1    2017
# Kyle Wiltjer        October 20, 1992           1            1    2017
# Stephen Zimmerman  September 9, 1996           1            1    2017
# Paul Zipser        February 18, 1994           1            1    2017
# Ivica Zubac           March 18, 1997           1            1    2017
#
#                                            college  games  games_started  \
# player
# ...

# %%
# split, train, and validate final_df

train, test = train_test_split(final_df, test_size=.20, 
                               random_state=123)
train, validate = train_test_split(train, test_size=.30, 
                                   random_state=123)

# %% [markdown]
# #

# %%
train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 2195 entries, Scott English to Norm Grekin
# Data columns (total 53 columns):
# position                  2195 non-null object
# age                       2195 non-null int64
# height_inches             2195 non-null int64
# weight_lbs                2195 non-null int64
# team                      2195 non-null object
# date_of_birth             2195 non-null object
# birth_city                2195 non-null int64
# birth_state               2195 non-null int64
# season                    2195 non-null int64
# college                   2195 non-null object
# games                     2195 non-null int64
# games_started             2195 non-null int64
# minutes_played            2195 non-null int64
# usage_%                   2195 non-null float64
# total_points              2195 non-null int64
# field_goals_made          2195 non-null int64
# field_goal_attempts       2195 non-null int64
# field_goal_%              2195 non-null float64
# ...

# %%
validate.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 941 entries, Lamar Green to Jack McMahon
# Data columns (total 53 columns):
# position                  941 non-null object
# age                       941 non-null int64
# height_inches             941 non-null int64
# weight_lbs                941 non-null int64
# team                      941 non-null object
# date_of_birth             941 non-null object
# birth_city                941 non-null int64
# birth_state               941 non-null int64
# season                    941 non-null int64
# college                   941 non-null object
# games                     941 non-null int64
# games_started             941 non-null int64
# minutes_played            941 non-null int64
# usage_%                   941 non-null float64
# total_points              941 non-null int64
# field_goals_made          941 non-null int64
# field_goal_attempts       941 non-null int64
# field_goal_%              941 non-null float64
# ...

# %%
test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 785 entries, Pat Riley* to Dave Jamerson
# Data columns (total 53 columns):
# position                  785 non-null object
# age                       785 non-null int64
# height_inches             785 non-null int64
# weight_lbs                785 non-null int64
# team                      785 non-null object
# date_of_birth             785 non-null object
# birth_city                785 non-null int64
# birth_state               785 non-null int64
# season                    785 non-null int64
# college                   785 non-null object
# games                     785 non-null int64
# games_started             785 non-null int64
# minutes_played            785 non-null int64
# usage_%                   785 non-null float64
# total_points              785 non-null int64
# field_goals_made          785 non-null int64
# field_goal_attempts       785 non-null int64
# field_goal_%              785 non-null float64
# ...
